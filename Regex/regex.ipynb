# %%
import re
text="python is easy"
res=re.findall("python",text)
print(res)
# Out:
# ['python']

# %%
import re
text="python is easy"
res=re.search("python",text)
print(res)
# Out:
# <re.Match object; span=(0, 6), match='python'>

# %%
import re
text="python sql power bi"
new=re.sub("power bi","Excel",text)
print(new)
# Out:
# python sql Excel

# %%
import re
text="python is easy"
new=re.rep("python","Excel",text)
print(new)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 3
#       1 import re
#       2 text="python is easy"
# ----> 3 new=re.rep("python","Excel",text)
#       4 print(new)
#
# AttributeError: module 're' has no attribute 'rep'

# %%
import re
text="Sales123"
digits=re.findall('\d',text)
print(digits)
# Out:
# ['1', '2', '3']

# %%
import re
text='sales:500  Profit:100'
digits=re.findall('\d+',text)
print(digits)
# Out:
# ['500', '100']

# %%
import re
mail1="john23@gmail.com"
mail2="web@.com"
mail3="123.com"
digits=re.search("\w+@\w+.\w+",mail1)
print(digits)
# Out:
# <re.Match object; span=(0, 16), match='john23@gmail.com'>

# %%
import re
num1="1234768902"
num2="4563289103"
num3="864209178"
digits=re.search("\d{10}",num3)
print(digits)
# Out:
# None

# %%
import re
num1="1234768902"
num2="4563289103"
num3="864209178"
digits=re.findall("\d{10}",num2)
print(digits)
# Out:
# ['4563289103']

# %%
import re
num1="1234768902"
num2="4563289103"
num3="864209178"
digits=re.findall("\d{10}",num3)
print(digits)
# Out:
# []
