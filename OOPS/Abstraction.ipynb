# %%
from abc import ABC,abstractmethod
class employee:
    @abstractmethod
    def work(self):
        return ("Working")
class developer(employee):
    def work(self):
        return ("Developing")
class HR(employee):
    def work(self):
        return ("Recruiting")
class Data_Analyst(employee):
    def work(self):
        return ("Analyse")
             
        

employee1=employee()
print(employee1.work())
developer1=developer()
print(developer1.work())
dataanalyst1=Data_Analyst()
print(dataanalyst1.work())
# Out:
# Working
# Developing
# Analyse

# %%
from abc import ABC,abstractmethod
class employee(ABC):
    @abstractmethod
    def work(self):
        return ("Working")
class developer(employee):
    def work(self):
        return ("Developing")
class HR(employee):
    def work(self):
        return ("Recruiting")
class Data_Analyst(employee):
    def work(self):
        return ("Analyse")
             
        


developer1=developer()
print(developer1.work())
dataanalyst1=Data_Analyst()
print(dataanalyst1.work())
# Out:
# Developing
# Analyse
