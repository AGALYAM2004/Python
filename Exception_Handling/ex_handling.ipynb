# %%
age=int(input("Enter age:"))
print(age)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 age=int(input("Enter age:"))
#       2 print(age)
#
# ValueError: invalid literal for int() with base 10: ''

# %%
try:
    age=int(inp("Enter age:"))
    print(age)
except:

    print("Invalid age")
# Out:
# Invalid age

# %%
try:
    age=int(inp("Enter the age:"))
    print(age)
except NameError:
    print("Invalid syntax")
# Out:
# Invalid syntax

# %%
try:
    print("processing")
except:
    print("Error")
finally:
    print("Completed")
# Out:
# processing
# Completed

# %%
try:
    O=open(r"C:\Users\AnudipCOA\Desktop\Data Analyst Portfolio\Python\File_Handling\data.csv","r")
except FileNotFoundError:
    print("File Not available in your directory/system")
finally:
    print("File Opened")
# Out:
# File Opened
