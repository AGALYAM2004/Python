# %%
import csv
with open(r"C:\Users\AnudipCOA\Desktop\Data Analyst Portfolio\Python\File_Handling\data.csv","w",newline='') as file:
    writer=csv.writer(file)
    writer.writerow(["Ink-bottle", 56])
    writer.writerow(["led-bulb", 34])

# %%
import csv
total_sales=0
Average=0
with open(r"C:\Users\AnudipCOA\Desktop\Data Analyst Portfolio\Python\File_Handling\data.csv","r") as file:
    reader=csv.DictReader(file)
    for row in reader:
        total_sales=total_sales+int(row["sales"])
        total_sales
        print(total_sales)
        number=len(row['sales'])
    average=total_sales/number
    print(average)
# Out:
# 56
# 90
# 45.0
